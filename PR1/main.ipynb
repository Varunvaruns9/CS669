# %%
# imports

import numpy as np
from DiagonalCommon import DiagonalCommon
from Common import Common
from DiagonalDifferent import DiagonalDifferent
from Different import Different
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# Group 9 Dataset - linearlySeparableData

data1 = np.loadtxt('Data/Group9/linearlySeparableData/Class1.txt')
data2 = np.loadtxt('Data/Group9/linearlySeparableData/Class2.txt')
data3 = np.loadtxt('Data/Group9/linearlySeparableData/Class3.txt')

print("\nSame covariance matrix with diagonal elements only:")
model = DiagonalCommon(data1, data2, data3)
model.result()
model.plot()

print("\nSame covariance matrix:")
model = Common(data1, data2, data3)
model.result()
model.plot()

print("\nDifferent covariance matrix with diagonal elements only:")
model = DiagonalDifferent(data1, data2, data3)
model.result()
model.plot()

print("\nDifferent covariance matrix:")
model = Different(data1, data2, data3)
model.result()
model.plot()
# Out:
# Same covariance matrix with diagonal elements only:
# Precision for Class 0: 1.0
# Recall for Class 0: 1.0
# F-measure for Class 0: 1.0
# Precision for Class 1: 1.0
# Recall for Class 1: 1.0
# F-measure for Class 1: 1.0
# Precision for Class 2: 1.0
# Recall for Class 2: 1.0
# F-measure for Class 2: 1.0
# Confusion Matrix:
# (Row - True, Column - Predicted)
#      0    1    2
# 0  125    0    0
# 1    0  125    0
# 2    0    0  125
# Mean Precision: 1.0
# Mean Recall: 1.0
# Mean F-measure: 1.0
# Accuracy: 1.0
# Same covariance matrix:
# Precision for Class 0: 1.0
# Recall for Class 0: 1.0
# F-measure for Class 0: 1.0
# Precision for Class 1: 1.0
# Recall for Class 1: 1.0
# F-measure for Class 1: 1.0
# Precision for Class 2: 1.0
# Recall for Class 2: 1.0
# F-measure for Class 2: 1.0
# Confusion Matrix:
# (Row - True, Column - Predicted)
#      0    1    2
# 0  125    0    0
# 1    0  125    0
# 2    0    0  125
# Mean Precision: 1.0
# Mean Recall: 1.0
# Mean F-measure: 1.0
# ...

# %%
# Group 9 Dataset - nonLinearlySeparableData

data1 = np.loadtxt('Data/Group11/nonLinearlySeparableData/Class1.txt')
data2 = np.loadtxt('Data/Group11/nonLinearlySeparableData/Class2.txt')
data3 = np.loadtxt('Data/Group11/nonLinearlySeparableData/Class3.txt')

print("\nSame covariance matrix with diagonal elements only:")
model = DiagonalCommon(data1, data2, data3)
model.result()
model.plot()

print("\nSame covariance matrix:")
model = Common(data1, data2, data3)
model.result()
model.plot()

print("\nDifferent covariance matrix with diagonal elements only:")
model = DiagonalDifferent(data1, data2, data3)
model.result()
model.plot()

print("\nDifferent covariance matrix:")
model = Different(data1, data2, data3)
model.result()
model.plot()
# Out:
# Same covariance matrix with diagonal elements only:
# Precision for Class 0: 0.0
# Recall for Class 0: 0.0
# F-measure for Class 0: nan
# Precision for Class 1: nan
# Recall for Class 1: 0.0
# F-measure for Class 1: nan
# Precision for Class 2: 0.3305084745762712
# Recall for Class 2: 0.6685714285714286
# F-measure for Class 2: 0.44234404536862004
# Confusion Matrix:
# (Row - True, Column - Predicted)
#     0  1    2
# 0   0  0  125
# 1  13  0  112
# 2  58  0  117
# Mean Precision: nan
# Mean Recall: 0.22285714285714286
# Mean F-measure: nan
# Accuracy: 0.2752941176470588
# Same covariance matrix:
# Precision for Class 0: 0.0
# Recall for Class 0: 0.0
# F-measure for Class 0: nan
# Precision for Class 1: nan
# Recall for Class 1: 0.0
# F-measure for Class 1: nan
# Precision for Class 2: 0.3532934131736527
# Recall for Class 2: 0.6742857142857143
# F-measure for Class 2: 0.46365422396856587
# Confusion Matrix:
# (Row - True, Column - Predicted)
#     0  1    2
# 0   0  0  125
# ...

# %%
# Group 9 Dataset - realData

data1 = np.loadtxt('Data/Group9/realData/Class1.txt')
data2 = np.loadtxt('Data/Group9/realData/Class2.txt')
data3 = np.loadtxt('Data/Group9/realData/Class3.txt')

print("\nSame covariance matrix with diagonal elements only:")
model = DiagonalCommon(data1, data2, data3)
model.result()
model.plot()

print("\nSame covariance matrix:")
model = Common(data1, data2, data3)
model.result()
model.plot()

print("\nDifferent covariance matrix with diagonal elements only:")
model = DiagonalDifferent(data1, data2, data3)
model.result()
model.plot()

print("\nDifferent covariance matrix:")
model = Different(data1, data2, data3)
model.result()
model.plot()
# Out:
# Same covariance matrix with diagonal elements only:
# Precision for Class 0: 0.9746835443037974
# Recall for Class 0: 0.9903536977491961
# F-measure for Class 0: 0.9824561403508772
# Precision for Class 1: 0.9850187265917603
# Recall for Class 1: 0.9722735674676525
# F-measure for Class 1: 0.9786046511627907
# Precision for Class 2: 1.0
# Recall for Class 2: 0.9949748743718593
# F-measure for Class 2: 0.9974811083123425
# Confusion Matrix:
# (Row - True, Column - Predicted)
#      0    1    2
# 0  616    6    0
# 1   15  526    0
# 2    1    2  594
# Mean Precision: 0.9865674236318525
# Mean Recall: 0.9858673798629026
# Mean F-measure: 0.9861806332753369
# Accuracy: 0.9863636363636363
# Same covariance matrix:
# Precision for Class 0: 0.9778481012658228
# Recall for Class 0: 0.9935691318327974
# F-measure for Class 0: 0.9856459330143541
# Precision for Class 1: 0.9869402985074627
# Recall for Class 1: 0.977818853974122
# F-measure for Class 1: 0.9823584029712163
# ...
